# %% [markdown]
# # HE 테스트

# %%
import numpy as np 
import numpy as np
import cv2
from skimage.io import imread
import matplotlib.pyplot as plt

# %%
img = imread("../data/FER2013/train/angry/Training_10316849.jpg")

fig = plt.figure(figsize=(5, 5))
fig_1 = fig.add_subplot(2,2,1)
fig_2 = fig.add_subplot(2,2,2)
fig_3 = fig.add_subplot(2,2,3)
fig_4 = fig.add_subplot(2,2,4)

# create a CLAHE object (Arguments are optional).
clahe1 = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(2,2))
cl1 = clahe1.apply(img)

clahe2 = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(4,4))
cl2 = clahe2.apply(img)

clahe3 = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(8,8))
cl3 = clahe3.apply(img)

fig_1.imshow(img, cmap='gray')
fig_2.imshow(cl1, cmap='gray')
fig_3.imshow(cl2, cmap='gray')
fig_4.imshow(cl3, cmap='gray')
plt.show()

# %% [markdown]
# # HE를 이용한 특성 추출

# %%
import os
import skimage.feature as feature 
import skimage.transform as transform
from PIL import Image
from skimage.io import imread
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %%
# train 폴더 변환
path_dir = '../data/FER2013/train'
file_list = os.listdir(path_dir)

for fname in file_list:
    # train 폴더 안의 폴더 경로
    temp_dir = os.path.join(path_dir, fname)
    for iname in tqdm(os.listdir(temp_dir),total=len(os.listdir(temp_dir)),position=0,leave=True):
        img = imread(os.path.join(temp_dir, iname), as_gray=True)
        clahe = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(4,4))
        cl1 = clahe.apply(img)
        
        # 저장되는 파일 포맷을 jpg로 지정
        # 중간에 TIF파일이 있는데 이거 때문에 오류나서 포맷을 지정함
        plt.imsave(f"../data/FER2013/HE/train/{fname}/{iname.split('.')[0]}.jpg", 
                   cl1, cmap="gray")
# Out:
#   0%|          | 0/3995 [00:00<?, ?it/s]
#   0%|          | 0/436 [00:00<?, ?it/s]
#   0%|          | 0/4097 [00:00<?, ?it/s]
#   0%|          | 0/7215 [00:00<?, ?it/s]
#   0%|          | 0/4965 [00:00<?, ?it/s]
#   0%|          | 0/4830 [00:00<?, ?it/s]
#   0%|          | 0/3171 [00:00<?, ?it/s]

# %%
# validation 폴더 변환
path_dir = '../data/FER2013/test'
file_list = os.listdir(path_dir)

for fname in file_list:
    # train 폴더 안의 폴더 경로
    temp_dir = os.path.join(path_dir, fname)
    for iname in tqdm(os.listdir(temp_dir),total=len(os.listdir(temp_dir)),position=0,leave=True):
        img = imread(os.path.join(temp_dir, iname), as_gray=True)
        clahe = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(4,4))
        cl1 = clahe.apply(img)
        
        # 저장되는 파일 포맷을 jpg로 지정
        # 중간에 TIF파일이 있는데 이거 때문에 오류나서 포맷을 지정함
        plt.imsave(f"../data/FER2013/HE/test/{fname}/{iname.split('.')[0]}.jpg", 
                   cl1, cmap="gray")
# Out:
#   0%|          | 0/958 [00:00<?, ?it/s]
#   0%|          | 0/111 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1774 [00:00<?, ?it/s]
#   0%|          | 0/1233 [00:00<?, ?it/s]
#   0%|          | 0/1247 [00:00<?, ?it/s]
#   0%|          | 0/831 [00:00<?, ?it/s]

# %% [markdown]
# # LBP를 이용한 학습

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.applications import EfficientNetB3, ResNet50

# %%
base_dir = '../data/FER2013/HE'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'test')

train_datagen = ImageDataGenerator(
      rescale=1/255,    
#     rotation_range=40,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     vertical_flip=True
)

validation_datagen = ImageDataGenerator(
    rescale=1/255
)

train_generator = train_datagen.flow_from_directory(
    train_dir, 
    color_mode='grayscale',
    target_size=(48,48),
    batch_size=100,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    color_mode='grayscale',
    target_size=(48,48),
    batch_size=100,
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
## 다른 모델

model = Sequential()
model.add(Conv2D(64, (1, 1), padding='same', activation='relu', 
                 input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(256, (5, 5),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2),padding="same"))
model.add(Dropout(0.25))


model.add(Flatten())

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))
model.summary()

model.compile(optimizer=Adam(learning_rate=1e-5), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 48, 48, 64)        128
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 48, 48, 128)       73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 48, 48, 128)       512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 48, 48, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 48, 48, 256)       819456
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 48, 48, 256)       1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 24, 24, 256)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 24, 24, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 147456)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               18874496
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               33024
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 19,806,087
# Trainable params: 19,804,423
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
## 다른 모델 논문 참고 모델
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same', activation='relu', 
                 input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(7, activation='softmax'))
model.summary()

model.compile(optimizer=Adam(learning_rate=1e-4), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 12, 12, 512)       2048
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 6, 6, 512)         2048
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,347,655
# Trainable params: 4,343,687
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
history = model.fit(train_generator, steps_per_epoch=280, epochs=50,
                    validation_data=validation_generator,
                    validation_steps=71)
# Out:
# Epoch 1/50
# 280/280 [==============================] - 126s 449ms/step - loss: 2.1584 - accuracy: 0.2424 - val_loss: 2.3685 - val_accuracy: 0.2323
# Epoch 2/50
# 280/280 [==============================] - 16s 56ms/step - loss: 1.9174 - accuracy: 0.3034 - val_loss: 2.0464 - val_accuracy: 0.3120
# Epoch 3/50
# 280/280 [==============================] - 13s 46ms/step - loss: 1.7886 - accuracy: 0.3482 - val_loss: 1.7542 - val_accuracy: 0.3814
# Epoch 4/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.6881 - accuracy: 0.3743 - val_loss: 1.4962 - val_accuracy: 0.4382
# Epoch 5/50
# 280/280 [==============================] - 13s 46ms/step - loss: 1.6020 - accuracy: 0.3993 - val_loss: 1.5017 - val_accuracy: 0.4573
# Epoch 6/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.5433 - accuracy: 0.4171 - val_loss: 1.4155 - val_accuracy: 0.4646
# Epoch 7/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.4758 - accuracy: 0.4413 - val_loss: 1.3882 - val_accuracy: 0.4863
# Epoch 8/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.4199 - accuracy: 0.4609 - val_loss: 1.3087 - val_accuracy: 0.5118
# Epoch 9/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.3729 - accuracy: 0.4769 - val_loss: 1.2628 - val_accuracy: 0.5287
# Epoch 10/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.3349 - accuracy: 0.4887 - val_loss: 1.2403 - val_accuracy: 0.5356
# Epoch 11/50
# 280/280 [==============================] - 13s 47ms/step - loss: 1.2862 - accuracy: 0.5076 - val_loss: 1.2285 - val_accuracy: 0.5410
# Epoch 12/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.2511 - accuracy: 0.5263 - val_loss: 1.2005 - val_accuracy: 0.5486
# Epoch 13/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.2201 - accuracy: 0.5349 - val_loss: 1.1816 - val_accuracy: 0.5455
# Epoch 14/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.1838 - accuracy: 0.5507 - val_loss: 1.1565 - val_accuracy: 0.5632
# Epoch 15/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.1494 - accuracy: 0.5613 - val_loss: 1.1577 - val_accuracy: 0.5689
# Epoch 16/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.1172 - accuracy: 0.5759 - val_loss: 1.1329 - val_accuracy: 0.5745
# Epoch 17/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.0949 - accuracy: 0.5848 - val_loss: 1.1120 - val_accuracy: 0.5841
# Epoch 18/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.0594 - accuracy: 0.6024 - val_loss: 1.0973 - val_accuracy: 0.5899
# Epoch 19/50
# 280/280 [==============================] - 13s 45ms/step - loss: 1.0338 - accuracy: 0.6096 - val_loss: 1.0951 - val_accuracy: 0.5925
# Epoch 20/50
# 280/280 [==============================] - 13s 46ms/step - loss: 1.0040 - accuracy: 0.6254 - val_loss: 1.0763 - val_accuracy: 0.5948
# Epoch 21/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.9773 - accuracy: 0.6377 - val_loss: 1.1019 - val_accuracy: 0.5945
# Epoch 22/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.9409 - accuracy: 0.6446 - val_loss: 1.0814 - val_accuracy: 0.5969
# Epoch 23/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.9152 - accuracy: 0.6560 - val_loss: 1.0791 - val_accuracy: 0.6089
# Epoch 24/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.8783 - accuracy: 0.6718 - val_loss: 1.0781 - val_accuracy: 0.6130
# Epoch 25/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.8510 - accuracy: 0.6809 - val_loss: 1.0805 - val_accuracy: 0.6111
# Epoch 26/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.8143 - accuracy: 0.6961 - val_loss: 1.0773 - val_accuracy: 0.6185
# Epoch 27/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.7771 - accuracy: 0.7089 - val_loss: 1.0759 - val_accuracy: 0.6193
# Epoch 28/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.7397 - accuracy: 0.7275 - val_loss: 1.0882 - val_accuracy: 0.6200
# Epoch 29/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.7111 - accuracy: 0.7363 - val_loss: 1.1175 - val_accuracy: 0.6161
# Epoch 30/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.6723 - accuracy: 0.7536 - val_loss: 1.1090 - val_accuracy: 0.6263
# Epoch 31/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.6416 - accuracy: 0.7643 - val_loss: 1.1060 - val_accuracy: 0.6272
# Epoch 32/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.6097 - accuracy: 0.7730 - val_loss: 1.1362 - val_accuracy: 0.6280
# Epoch 33/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.5813 - accuracy: 0.7871 - val_loss: 1.1358 - val_accuracy: 0.6246
# Epoch 34/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.5378 - accuracy: 0.8024 - val_loss: 1.1588 - val_accuracy: 0.6239
# Epoch 35/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.5214 - accuracy: 0.8072 - val_loss: 1.2424 - val_accuracy: 0.6179
# Epoch 36/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.4894 - accuracy: 0.8212 - val_loss: 1.2152 - val_accuracy: 0.6237
# Epoch 37/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.4573 - accuracy: 0.8322 - val_loss: 1.2234 - val_accuracy: 0.6289
# Epoch 38/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.4387 - accuracy: 0.8383 - val_loss: 1.2366 - val_accuracy: 0.6294
# Epoch 39/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.4166 - accuracy: 0.8497 - val_loss: 1.2646 - val_accuracy: 0.6292
# Epoch 40/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.4007 - accuracy: 0.8540 - val_loss: 1.2795 - val_accuracy: 0.6272
# Epoch 41/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.3743 - accuracy: 0.8639 - val_loss: 1.3336 - val_accuracy: 0.6307
# Epoch 42/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.3588 - accuracy: 0.8698 - val_loss: 1.3023 - val_accuracy: 0.6320
# Epoch 43/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.3249 - accuracy: 0.8836 - val_loss: 1.3478 - val_accuracy: 0.6315
# Epoch 44/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.3232 - accuracy: 0.8838 - val_loss: 1.3844 - val_accuracy: 0.6301
# Epoch 45/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.3008 - accuracy: 0.8930 - val_loss: 1.4064 - val_accuracy: 0.6317
# Epoch 46/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.2852 - accuracy: 0.8988 - val_loss: 1.4170 - val_accuracy: 0.6279
# Epoch 47/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.2776 - accuracy: 0.8999 - val_loss: 1.4220 - val_accuracy: 0.6328
# Epoch 48/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.2704 - accuracy: 0.9018 - val_loss: 1.4574 - val_accuracy: 0.6221
# Epoch 49/50
# 280/280 [==============================] - 13s 45ms/step - loss: 0.2537 - accuracy: 0.9100 - val_loss: 1.4899 - val_accuracy: 0.6258
# Epoch 50/50
# 280/280 [==============================] - 13s 46ms/step - loss: 0.2422 - accuracy: 0.9141 - val_loss: 1.5184 - val_accuracy: 0.6234
