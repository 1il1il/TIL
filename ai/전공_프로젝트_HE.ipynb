# %% [markdown]
# # HE 테스트

# %%
import numpy as np 
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../data/telemoji/train/angry/0000792211b64f6a59bd2d95fee49eabe6373ec1d88f2285bae2ba9b.jpg", 0)

fig = plt.figure(figsize=(10, 10))
fig_1 = fig.add_subplot(1,2,1)
fig_2 = fig.add_subplot(1,2,2)

# create a CLAHE object (Arguments are optional).
clahe = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(4,4))
cl1 = clahe.apply(img)

fig_1.imshow(img, cmap='gray')
fig_2.imshow(cl1, cmap='gray')
plt.show()

# %% [markdown]
# # LBP를 이용한 특성 추출

# %%
import os
import skimage.feature as feature 
import skimage.transform as transform
from PIL import Image
from skimage.io import imread
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %%
# train 폴더 변환
path_dir = '../data/FER2013/train'
file_list = os.listdir(path_dir)

for fname in file_list:
    # train 폴더 안의 폴더 경로
    temp_dir = os.path.join(path_dir, fname)
    for iname in tqdm(os.listdir(temp_dir),total=len(os.listdir(temp_dir)),position=0,leave=True):
        img = imread(os.path.join(temp_dir, iname), as_gray=True)
        LBP = feature.local_binary_pattern(img, 8, 1, method='ror')
        
        # 저장되는 파일 포맷을 jpg로 지정
        # 중간에 TIF파일이 있는데 이거 때문에 오류나서 포맷을 지정함
        plt.imsave(f"../data/FER2013/LBP/train/{fname}/{iname.split('.')[0]}.jpg", 
                   LBP, cmap="gray")
# Out:
#   0%|          | 0/3995 [00:00<?, ?it/s]
#   0%|          | 0/436 [00:00<?, ?it/s]
#   0%|          | 0/4097 [00:00<?, ?it/s]
#   0%|          | 0/7215 [00:00<?, ?it/s]
#   0%|          | 0/4965 [00:00<?, ?it/s]
#   0%|          | 0/4830 [00:00<?, ?it/s]
#   0%|          | 0/3171 [00:00<?, ?it/s]

# %%
# validation 폴더 변환
path_dir = '../data/FER2013/test'
file_list = os.listdir(path_dir)

for fname in file_list:
    # train 폴더 안의 폴더 경로
    temp_dir = os.path.join(path_dir, fname)
    for iname in tqdm(os.listdir(temp_dir),total=len(os.listdir(temp_dir)),position=0,leave=True):
        img = imread(os.path.join(temp_dir, iname), as_gray=True)
        LBP = feature.local_binary_pattern(img, 8, 1, method='ror')
        
        # 저장되는 파일 포맷을 jpg로 지정
        # 중간에 TIF파일이 있는데 이거 때문에 오류나서 포맷을 지정함
        plt.imsave(f"../data/FER2013/LBP/test/{fname}/{iname.split('.')[0]}.jpg", 
                   LBP, cmap="gray")
# Out:
#   0%|          | 0/958 [00:00<?, ?it/s]
#   0%|          | 0/111 [00:00<?, ?it/s]
#   0%|          | 0/1024 [00:00<?, ?it/s]
#   0%|          | 0/1774 [00:00<?, ?it/s]
#   0%|          | 0/1233 [00:00<?, ?it/s]
#   0%|          | 0/1247 [00:00<?, ?it/s]
#   0%|          | 0/831 [00:00<?, ?it/s]

# %% [markdown]
# # LBP를 이용한 학습

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.applications import EfficientNetB3, ResNet50

# %%
base_dir = '../data/FER2013/LBP'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'test')

train_datagen = ImageDataGenerator(
      rescale=1/255,    
#     rotation_range=40,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     vertical_flip=True
)

validation_datagen = ImageDataGenerator(
    rescale=1/255
)

train_generator = train_datagen.flow_from_directory(
    train_dir, 
    color_mode='grayscale',
    target_size=(48,48),
    batch_size=100,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    color_mode='grayscale',
    target_size=(48,48),
    batch_size=100,
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
## 다른 모델

model = Sequential()
model.add(Conv2D(64, (1, 1), padding='same', activation='relu', 
                 input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(256, (5, 5),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2),padding="same"))
model.add(Dropout(0.25))


model.add(Flatten())

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))
model.summary()

model.compile(optimizer=Adam(learning_rate=1e-5), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        128
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 48, 48, 128)       73856
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 48, 48, 128)       512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 48, 48, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 48, 48, 256)       819456
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 48, 48, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 256)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 24, 24, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 147456)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               18874496
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128)               512
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               33024
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 19,806,087
# Trainable params: 19,804,423
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
## 다른 모델 논문 참고 모델
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same', activation='relu', 
                 input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(7, activation='softmax'))
model.summary()

model.compile(optimizer=Adam(learning_rate=1e-3), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 24, 24, 128)       73856
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 12, 12, 512)       2048
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 6, 6, 512)         2048
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               131584
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 7)                 3591
# =================================================================
# Total params: 4,347,655
# Trainable params: 4,343,687
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
history = model.fit(train_generator, steps_per_epoch=280, epochs=40,
                    validation_data=validation_generator,
                    validation_steps=71)
# Out:
# Epoch 1/40
# 280/280 [==============================] - 127s 453ms/step - loss: 1.9421 - accuracy: 0.2797 - val_loss: 2.5926 - val_accuracy: 0.1158
# Epoch 2/40
# 280/280 [==============================] - 16s 57ms/step - loss: 1.5821 - accuracy: 0.3969 - val_loss: 1.8307 - val_accuracy: 0.2599
# Epoch 3/40
# 280/280 [==============================] - 13s 47ms/step - loss: 1.4184 - accuracy: 0.4581 - val_loss: 1.4512 - val_accuracy: 0.4359
# Epoch 4/40
# 280/280 [==============================] - 13s 46ms/step - loss: 1.3175 - accuracy: 0.4946 - val_loss: 1.3534 - val_accuracy: 0.4848
# Epoch 5/40
# 280/280 [==============================] - 13s 46ms/step - loss: 1.2388 - accuracy: 0.5269 - val_loss: 1.2552 - val_accuracy: 0.5141
# Epoch 6/40
# 280/280 [==============================] - 13s 46ms/step - loss: 1.1767 - accuracy: 0.5470 - val_loss: 1.2508 - val_accuracy: 0.5244
# Epoch 7/40
# 280/280 [==============================] - 13s 46ms/step - loss: 1.1229 - accuracy: 0.5683 - val_loss: 1.2861 - val_accuracy: 0.5194
# Epoch 8/40
# 280/280 [==============================] - 13s 46ms/step - loss: 1.0505 - accuracy: 0.6007 - val_loss: 1.1782 - val_accuracy: 0.5563
# Epoch 9/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.9759 - accuracy: 0.6332 - val_loss: 1.2056 - val_accuracy: 0.5511
# Epoch 10/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.9024 - accuracy: 0.6642 - val_loss: 1.2338 - val_accuracy: 0.5427
# Epoch 11/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.8473 - accuracy: 0.6830 - val_loss: 1.3141 - val_accuracy: 0.5404
# Epoch 12/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.7551 - accuracy: 0.7216 - val_loss: 1.2581 - val_accuracy: 0.5651
# Epoch 13/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.6864 - accuracy: 0.7460 - val_loss: 1.3365 - val_accuracy: 0.5663
# Epoch 14/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.6187 - accuracy: 0.7765 - val_loss: 1.3056 - val_accuracy: 0.5730
# Epoch 15/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.5371 - accuracy: 0.8067 - val_loss: 1.4880 - val_accuracy: 0.5655
# Epoch 16/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.4808 - accuracy: 0.8245 - val_loss: 1.4649 - val_accuracy: 0.5670
# Epoch 17/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.4569 - accuracy: 0.8350 - val_loss: 1.5844 - val_accuracy: 0.5587
# Epoch 18/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.4270 - accuracy: 0.8472 - val_loss: 1.6149 - val_accuracy: 0.5641
# Epoch 19/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.3645 - accuracy: 0.8712 - val_loss: 1.6117 - val_accuracy: 0.5631
# Epoch 20/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.3513 - accuracy: 0.8756 - val_loss: 1.6194 - val_accuracy: 0.5523
# Epoch 21/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.3130 - accuracy: 0.8910 - val_loss: 1.6551 - val_accuracy: 0.5751
# Epoch 22/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.2819 - accuracy: 0.9023 - val_loss: 1.7456 - val_accuracy: 0.5746
# Epoch 23/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.2885 - accuracy: 0.8970 - val_loss: 1.7508 - val_accuracy: 0.5545
# Epoch 24/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.2548 - accuracy: 0.9113 - val_loss: 1.7375 - val_accuracy: 0.5796
# Epoch 25/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.2353 - accuracy: 0.9172 - val_loss: 1.9586 - val_accuracy: 0.5394
# Epoch 26/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.2642 - accuracy: 0.9071 - val_loss: 1.7417 - val_accuracy: 0.5818
# Epoch 27/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.2134 - accuracy: 0.9241 - val_loss: 1.9486 - val_accuracy: 0.5690
# Epoch 28/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.2394 - accuracy: 0.9150 - val_loss: 1.7749 - val_accuracy: 0.5790
# Epoch 29/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1973 - accuracy: 0.9317 - val_loss: 1.9281 - val_accuracy: 0.5744
# Epoch 30/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1859 - accuracy: 0.9358 - val_loss: 1.9380 - val_accuracy: 0.5779
# Epoch 31/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1761 - accuracy: 0.9393 - val_loss: 1.9004 - val_accuracy: 0.5863
# Epoch 32/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1856 - accuracy: 0.9361 - val_loss: 1.9049 - val_accuracy: 0.5808
# Epoch 33/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1713 - accuracy: 0.9406 - val_loss: 2.0240 - val_accuracy: 0.5717
# Epoch 34/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1718 - accuracy: 0.9419 - val_loss: 1.9076 - val_accuracy: 0.5796
# Epoch 35/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1607 - accuracy: 0.9444 - val_loss: 2.0128 - val_accuracy: 0.5800
# Epoch 36/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1537 - accuracy: 0.9469 - val_loss: 1.9354 - val_accuracy: 0.5794
# Epoch 37/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1528 - accuracy: 0.9479 - val_loss: 2.0096 - val_accuracy: 0.5846
# Epoch 38/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1586 - accuracy: 0.9447 - val_loss: 2.0092 - val_accuracy: 0.5839
# Epoch 39/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1553 - accuracy: 0.9475 - val_loss: 2.0454 - val_accuracy: 0.5775
# Epoch 40/40
# 280/280 [==============================] - 13s 47ms/step - loss: 0.1385 - accuracy: 0.9523 - val_loss: 2.1317 - val_accuracy: 0.5749
